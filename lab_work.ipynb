# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderEvseev46/python_homework/blob/dev/lab_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа

# %% [markdown]
# Баллы за секции:
# - *Задание 1* - 10 баллов
# - *Задание 2* - 20 баллов
# - *Задание 3* - 30 баллов
# - **Итого** - 60 баллов
#
# Оценка за лабу $ = \frac{score}{6}$

# %% [markdown]
# ## Внимание! Attention! Achtung!

# %% [markdown]
# **Данная лабораторная работа является блокирующей**, т.е. если лабораторная работа не выполнена, то оценка за курс - неуд.
#
# Лабораторная работа считается выполненной, если **за каждое из заданий получено не менее 2 баллов**.

# %% [markdown]
# ## Формат сдачи лабораторной работы

# %% [markdown]
# Данная лабораторная работа сдается так же, как и проект - заполняете данный ноутбук, отправляете его через GitHub с указанием проверяющего.

# %% [markdown]
# **Ассистенты не будут запускать ячейки кода, а смотреть на выведенный результат и код. Если ячейка кода не запущена - балл не ставится, даже при правильно написанном коде.**
#
# ***(Комментарии что курс по Python легче чем по C++ учтены)***

# %% [markdown]
# >**Примечание**
# >
# >Данные задания вдохновлены предметом "Введение в анализ данных" 2 курса, по итогу которого идёт отбор на DS-поток. Если вы видите себя в смежных областях, советуем выполнить данную лабораторку по максимуму.

# %%
# Всё необходимое для выполнения данной лабораторной работы!
import requests
from time import sleep

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Задание 1. Парсинг - 10 баллов

# %% [markdown]
# В этом задании Вам предстоит работать с API сайта <a target="_blank" href="hh.ru">hh.ru</a>. Документация доступна по <a target="_blank" href="https://github.com/hhru/api/blob/master/docs/vacancies.md#search">ссылке</a>.

# %% [markdown]
# <b><font color="red">Внимание!</font> При работе с API не забывайте делать паузы между запросами, иначе вас забанят. Просрочка дедлайна по этой причине не принимается!</b>

# %% [markdown]
# **Задача:**
# 1. выбрать 5 интересующих вас профессий (не смежных, т.е. Аналатик и Data Engineer не считается корректным)
# 2. затем получить доступные по данным профессиям вакансии в Москве и выделить их физические координаты
# 3. нанести полученные координаты на карту местоположения компаний

# %% [markdown]
# *Пример запроса для профессии:*

# %%
URL = 'https://api.hh.ru/vacancies'

params = {
    'text': "Физик-ядерщик",
    'area': 1,
    'page': 0,
    'per_page': 10
}

data = requests.get(URL, params).json()

# %% [markdown]
# Если Ваш запрос прошел успешно, то вы получите следующие ключи (значения данных ключей вы найдете по ссылке на документацию):

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'page', 'per_page', 'clusters', 'arguments', 'fixes', 'suggests', 'alternate_url'])

# %% [markdown]
# >**Примечание**
# >
# >В `data['pages']` будет хранится количество найденных страниц вакансий - для корректного сбора данных Вам нужно пробежать по **КАЖДОЙ** странице и сделать соотвествующие запросы.

# %% [markdown]
# >**Совет**
# >
# >Посмотрите что хранится в `items`!

# %% [markdown]
# (1 балл) Выберете для нас 5 наиболее интересных специальностей и получите по ним имеющиеся вакансии:

# %%
jobs = ['мясник', 'психолог', 'уборщик', 'массажист', 'учитель']
params = [{'text': jobs[i], 'area': 1, 'page': 0, 'per_page': 10} for i in range(5)]
data = [requests.get(URL, params[i]).json() for i in range(5)]
data
# Out:
# [{'items': [{'id': '98821262',
#     'premium': False,
#     'name': 'Менеджер по эксплуатации транспорта',
#     'department': {'id': '23186-23186-sugar',
#      'name': '«РУСАГРО», Сахарное бизнес-направление'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T16:21:49+0300',
#     'created_at': '2024-05-13T16:21:49+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98821262',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98821262?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98821262',
#     'relations': [],
#     'employer': {'id': '23186',
#      'name': 'Группа Компаний РУСАГРО',
#      'url': 'https://api.hh.ru/employers/23186',
#      'alternate_url': 'https://hh.ru/employer/23186',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=23186',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в аналогичной должности. Уверенный пользователь ПК.',
#      'responsibility': 'Организация работы по своевременному техническому обслуживанию транспорта . Принятие мер по своевременному устранению неисправностей. Организация ремонта тракторной техники. Составление планов по...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '40', 'name': 'Другое'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98646758',
#     'premium': False,
#     'name': 'Помощник/Помощница повара на Пищевое производство в Москве',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 122500,
#      'to': 315000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': None,
#      'street': None,
#      'building': None,
#      'lat': None,
#      'lng': None,
#      'description': None,
#      'raw': None,
#      'metro': {'station_name': 'Павелецкая',
#       'line_name': 'Кольцевая',
#       'station_id': '5.102',
#       'line_id': '5',
#       'lat': 55.731414,
#       'lng': 37.636294},
#      'metro_stations': [{'station_name': 'Павелецкая',
#        'line_name': 'Кольцевая',
#        'station_id': '5.102',
#        'line_id': '5',
#        'lat': 55.731414,
#        'lng': 37.636294}],
#      'id': '14153865'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-09T08:11:10+0300',
#     'created_at': '2024-05-09T08:11:10+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98646758',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98646758?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98646758',
#     'relations': [],
#     'employer': {'id': '9980978',
#      'name': 'Глобальные Решения',
#      'url': 'https://api.hh.ru/employers/9980978',
#      'alternate_url': 'https://hh.ru/employer/9980978',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6090154.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6090153.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1117389.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9980978',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Рacсматриваем кандидaтов бeз опыта! Поставить могут на любую позицию, нужно быть к этому готовыми. Обучаемость, работоспособность, ответственность, внимательность, аккуратность.',
#      'responsibility': 'Работать в горячих и холодных цехах. Лепить, фасовать, упаковывать, стикеровать, нарезать, жарить.'},
#     'contacts': None,
#     'schedule': {'id': 'flyInFlyOut', 'name': 'Вахтовый метод'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '95777196',
#     'premium': False,
#     'name': 'Менеджер по работе с ключевыми клиентами',
#     'department': {'id': '23186-23186-sugar',
#      'name': '«РУСАГРО», Сахарное бизнес-направление'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-08T10:43:58+0300',
#     'created_at': '2024-05-08T10:43:58+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=95777196',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/95777196?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/95777196',
#     'relations': [],
#     'employer': {'id': '23186',
#      'name': 'Группа Компаний РУСАГРО',
#      'url': 'https://api.hh.ru/employers/23186',
#      'alternate_url': 'https://hh.ru/employer/23186',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=23186',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее образование. Опыт работы с каналом e-commerce (FMCG), маркетплайсами и онлайн площадками. Отличные знания MS Office(Excel, Word, PowerPoint...',
#      'responsibility': 'Задачи Менеджера по работе с ключевыми клиентами: Развивать e-commerce продаж на крупнейших маркетплейсах и онлайн площадках. Разрабатывать, реализовывать и...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '70',
#       'name': 'Менеджер по продажам, менеджер по работе с клиентами'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98256910',
#     'premium': False,
#     'name': 'Мясник',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 100000,
#      'to': 120000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'посёлок завода Мосрентген',
#      'street': 'площадь Мосрентген',
#      'building': None,
#      'lat': 55.620967,
#      'lng': 37.47377,
#      'description': None,
#      'raw': 'посёлок завода Мосрентген, площадь Мосрентген',
#      'metro': None,
#      'metro_stations': [],
#      'id': '3895887'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-02T15:44:53+0300',
#     'created_at': '2024-05-02T15:44:53+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98256910',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98256910?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98256910',
#     'relations': [],
#     'employer': {'id': '2006006',
#      'name': 'Репин Дмитрий Евгеньевич',
#      'url': 'https://api.hh.ru/employers/2006006',
#      'alternate_url': 'https://hh.ru/employer/2006006',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2006006',
#      'accredited_it_employer': False,
#      'trusted': False},
#     'snippet': {'requirement': None,
#      'responsibility': 'В мясной цех при магазине требуется <highlighttext>мясник</highlighttext> обвальщик-кулинар. Сменный график работы по договоренности с 9:00-19:00. '},
#     'contacts': None,
#     'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98790805',
#     'premium': False,
#     'name': 'Дизайнер упаковки',
#     'department': {'id': '23186-23186-meat',
#      'name': '«РУСАГРО», Мясное бизнес-направление'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Валовая улица',
#      'building': '35',
#      'lat': 55.729275,
#      'lng': 37.626313,
#      'description': None,
#      'raw': 'Москва, Валовая улица, 35',
#      'metro': {'station_name': 'Добрынинская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.36',
#       'line_id': '5',
#       'lat': 55.728994,
#       'lng': 37.622533},
#      'metro_stations': [{'station_name': 'Добрынинская',
#        'line_name': 'Кольцевая',
#        'station_id': '5.36',
#        'line_id': '5',
#        'lat': 55.728994,
#        'lng': 37.622533}],
#      'id': '597319'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T12:26:12+0300',
#     'created_at': '2024-05-13T12:26:12+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98790805',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98790805?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98790805',
#     'relations': [],
#     'employer': {'id': '23186',
#      'name': 'Группа Компаний РУСАГРО',
#      'url': 'https://api.hh.ru/employers/23186',
#      'alternate_url': 'https://hh.ru/employer/23186',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=23186',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт разработки дизайн-макетов упаковки продуктов питания, POSM, материалов для ATL и BTL - активностей. Опыт работы в должностях, связанных с...',
#      'responsibility': 'Адаптация и изменение существующих дизайн-макетов упаковки. Разработка рекламных материалов по утвержденной дизайн-концепции. Разработку дизайн-концепции и дизайн-макетов...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97755065',
#     'premium': False,
#     'name': 'Повар холодного цеха',
#     'department': {'id': 'tsum-52389-horeca', 'name': 'HoReCa'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': 75000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': None,
#      'street': None,
#      'building': None,
#      'lat': 55.75999999999371,
#      'lng': 37.63999999999997,
#      'description': None,
#      'raw': 'Москва, ул. Петровка, 2',
#      'metro': None,
#      'metro_stations': [],
#      'id': '312693'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-23T19:55:16+0300',
#     'created_at': '2024-04-23T19:55:16+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97755065',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97755065?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97755065',
#     'relations': [],
#     'employer': {'id': '52389',
#      'name': 'ЦУМ, ТД',
#      'url': 'https://api.hh.ru/employers/52389',
#      'alternate_url': 'https://hh.ru/employer/52389',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/901928.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/4048399.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/4048400.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=52389',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': '...повар, грильщик, заготовщик, повар горячего цеха (г.ц.), повар холодного цеха (х.ц.),работа на супах, <highlighttext>мясника</highlighttext>, сушиста, помощник повара.',
#      'responsibility': 'Приготовление различных блюд. Соблюдение санитарных норм и правил.'},
#     'contacts': None,
#     'schedule': {'id': 'shift', 'name': 'Сменный график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97894185',
#     'premium': False,
#     'name': 'Руководитель управления транспортной логистики',
#     'department': {'id': '23186-23186-meat',
#      'name': '«РУСАГРО», Мясное бизнес-направление'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-25T12:24:55+0300',
#     'created_at': '2024-04-25T12:24:55+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97894185',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97894185?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97894185',
#     'relations': [],
#     'employer': {'id': '23186',
#      'name': 'Группа Компаний РУСАГРО',
#      'url': 'https://api.hh.ru/employers/23186',
#      'alternate_url': 'https://hh.ru/employer/23186',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=23186',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее образование (техническое, экономическое). Опыт работы в транспортной логистике (директор по доставке, руководитель транспортной логистики). Знание специфики рынка транспортных услуг. ',
#      'responsibility': 'Стратегическое управление транспортной логистикой: 1. Эффективность и автоматизация: Организация и оптимизация доставки. Контроль маршрутизации. Разработка бизнес-требований для системы управления...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '172',
#       'name': 'Руководитель отдела логистики'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97912431',
#     'premium': False,
#     'name': 'Руководитель отдела продаж',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 250000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Отрадная улица',
#      'building': '2Б',
#      'lat': 55.857781,
#      'lng': 37.6024,
#      'description': None,
#      'raw': 'Москва, Отрадная улица, 2Б',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15604606'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T14:14:36+0300',
#     'created_at': '2024-05-13T14:14:36+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97912431',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97912431?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97912431',
#     'relations': [],
#     'employer': {'id': '10798071',
#      'name': 'Асилаб',
#      'url': 'https://api.hh.ru/employers/10798071',
#      'alternate_url': 'https://hh.ru/employer/10798071',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6563422.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6563421.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1235745.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10798071',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт переговоров с ЛПР в b2b сегменте. — Опыт внедрения CRM. — Понимание, как грамотно работать с коллективом: опыт конструктивного...',
#      'responsibility': 'Функционал: — Развитие направления “Продажи высокотехнологичных продуктов собственного производства”. — Структурирование и организация бизнес-процессов в существующем отделе продаж. — Разработка и внедрение...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '106',
#       'name': 'Руководитель отдела продаж'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '96995166',
#     'premium': False,
#     'name': 'Мясник-заготовщик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Калининская линия',
#      'building': 'метро Площадь Ильича',
#      'lat': 55.747024,
#      'lng': 37.680589,
#      'description': None,
#      'raw': 'Москва, Калининская линия, метро Площадь Ильича',
#      'metro': None,
#      'metro_stations': [],
#      'id': '607541'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T09:58:40+0300',
#     'created_at': '2024-05-13T09:58:40+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=96995166',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/96995166?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/96995166',
#     'relations': [],
#     'employer': {'id': '2127513',
#      'name': 'Омега',
#      'url': 'https://api.hh.ru/employers/2127513',
#      'alternate_url': 'https://hh.ru/employer/2127513',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2127513',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы. Наличие медицинской книжки.',
#      'responsibility': 'Приготовление заготовок из мяса птицы, рыбы. Поддержание чистоты на рабочем месте.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '96728571',
#     'premium': False,
#     'name': 'Повар-мясник',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 69600, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': '1-я Мытищинская улица',
#      'building': '17',
#      'lat': 55.800281,
#      'lng': 37.644827,
#      'description': None,
#      'raw': 'Москва, 1-я Мытищинская улица, 17',
#      'metro': {'station_name': 'Алексеевская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.8',
#       'line_id': '6',
#       'lat': 55.807794,
#       'lng': 37.638699},
#      'metro_stations': [{'station_name': 'Алексеевская',
#        'line_name': 'Калужско-Рижская',
#        'station_id': '6.8',
#        'line_id': '6',
#        'lat': 55.807794,
#        'lng': 37.638699}],
#      'id': '223191'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-19T08:53:06+0300',
#     'created_at': '2024-04-19T08:53:06+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=96728571',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/96728571?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/96728571',
#     'relations': [],
#     'employer': {'id': '99070',
#      'name': 'Спецсвязь России (ГЦСС) ФГУП',
#      'url': 'https://api.hh.ru/employers/99070',
#      'alternate_url': 'https://hh.ru/employer/99070',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/3878903.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/3878904.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/859507.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=99070',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Профессиональное образование. Знание и соблюдение санитарно-эпидемиологических требований и принципы работы и правила эксплуатации используемого оборудования. Чистоплотность, аккуратность, порядочность, ответственность...',
#      'responsibility': 'Разделка и приготовление заготовок из мяса и рыбы. Приготовление блюд из мяса и рыбы. Соблюдение санитарных норм и правил в...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   'found': 137,
#   'pages': 14,
#   'page': 0,
#   'per_page': 10,
#   'clusters': None,
#   'arguments': None,
#   'fixes': None,
#   'suggests': None,
#   'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&items_on_page=10&text=%D0%BC%D1%8F%D1%81%D0%BD%D0%B8%D0%BA'},
#  {'items': [{'id': '95816441',
#     'premium': False,
#     'name': 'Product & Process Implementation Technologist\\Технолог по внедрению продуктов и процессов (Ступино)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-15T23:11:32+0300',
#     'created_at': '2024-04-15T23:11:32+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=95816441',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/95816441?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/95816441',
#     'relations': [],
#     'employer': {'id': '205',
#      'name': 'Марс',
#      'url': 'https://api.hh.ru/employers/205',
#      'alternate_url': 'https://hh.ru/employer/205',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/3188405.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/3188404.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/686818.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=205',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Оконченное высшее образование: степень бакалавра/магистра/эквивалентная степень в области естественных наук / инженерного дела / науки о пищевых продуктах / технологии / упаковки...',
#      'responsibility': 'Обеспечивать пусконаладку и ввод в эксплуатацию продуктов и технологических процессов, при соблюдении проектных KPI и KQA продуктов/брендов с соблюдением...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '49', 'name': 'Технолог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98544464',
#     'premium': False,
#     'name': 'Помощник психолога',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 40000, 'to': 80000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-07T13:15:29+0300',
#     'created_at': '2024-05-07T13:15:29+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98544464',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98544464?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98544464',
#     'relations': [],
#     'employer': {'id': '4880620',
#      'name': 'Центр психологии Паззлы',
#      'url': 'https://api.hh.ru/employers/4880620',
#      'alternate_url': 'https://hh.ru/employer/4880620',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1260351.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/6661730.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6661731.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4880620',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Психологическое образование или профессиональная переподготовка (оконченное, в процессе получения). Поставленная речь. Высокий уровень эмпатии. Умение работать в системе и в...',
#      'responsibility': 'Онлайн работа с клиентами центра по методике психоэнергетической коррекции личности «Паззлы». (обучаем). Онлайн работа с информацией в мессенджерах и чатах. '},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '101', 'name': 'Психолог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97805676',
#     'premium': False,
#     'name': 'Психолог в онлайн школу',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-24T12:11:37+0300',
#     'created_at': '2024-04-24T12:11:37+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97805676',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97805676?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97805676',
#     'relations': [],
#     'employer': {'id': '6072187',
#      'name': 'Забелин Сергей Евгеньевич',
#      'url': 'https://api.hh.ru/employers/6072187',
#      'alternate_url': 'https://hh.ru/employer/6072187',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=6072187',
#      'accredited_it_employer': False,
#      'trusted': False},
#     'snippet': {'requirement': 'Наличие психологического образования. Грамотная, четкая речь. Владение современными интернет-сервисами на базовом уровне. Возможность записывать качественные видеоматериалы на дому. ',
#      'responsibility': 'При отклике на вакансию соискателю нужно будет записать небольшое тестовое видео для оценки качества картинки и подачи материала.'},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '101', 'name': 'Психолог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98709524',
#     'premium': False,
#     'name': 'Директор по управлению персоналом (ЛНР)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 300000, 'to': 400000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-11T20:00:27+0300',
#     'created_at': '2024-05-11T20:00:27+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98709524',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98709524?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98709524',
#     'relations': [],
#     'employer': {'id': '5587422',
#      'name': 'Союзметаллсервис',
#      'url': 'https://api.hh.ru/employers/5587422',
#      'alternate_url': 'https://hh.ru/employer/5587422',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1270943.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6704082.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6704083.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5587422',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее образование («Управление персоналом, «Экономика» «Юриспруденция», «<highlighttext>Психология</highlighttext>»). Дополнительное профессиональное образование - программы профессиональной переподготовки в области управления персоналом или в области...',
#      'responsibility': 'Организация работы управления по персоналу, в т.ч. составления установленной отчетности и контроль за соблюдением норм трудового законодательства. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '38',
#       'name': 'Директор по персоналу (HRD)'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98566623',
#     'premium': False,
#     'name': 'Frontend-разработчик (Junior)',
#     'department': None,
#     'has_test': True,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-07T18:09:37+0300',
#     'created_at': '2024-05-07T18:09:37+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98566623',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98566623?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98566623',
#     'relations': [],
#     'employer': {'id': '4219',
#      'name': 'Tele2',
#      'url': 'https://api.hh.ru/employers/4219',
#      'alternate_url': 'https://hh.ru/employer/4219',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/615008.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/615009.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/231601.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4219',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Работа в роли разработчика front-end от 1-го года. Оконченное высшее образование. Знание JavaScript, HTML и CSS. ',
#      'responsibility': 'Разрабатывать крупные сервисы, которые постоянно развиваются и изменяются, а также поддерживать и улучшать существующие проекты компании. Работать в команде. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '95111445',
#     'premium': False,
#     'name': 'Карьерный консультант',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 58000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Рязанский проспект',
#      'building': '7',
#      'lat': 55.731947,
#      'lng': 37.734937,
#      'description': None,
#      'raw': 'Москва, Рязанский проспект, 7',
#      'metro': None,
#      'metro_stations': [],
#      'id': '5731351'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-19T10:51:12+0300',
#     'created_at': '2024-04-19T10:51:12+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=95111445',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/95111445?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/95111445',
#     'relations': [],
#     'employer': {'id': '2198536',
#      'name': 'ГБОУ ДПО Центр Профессионал',
#      'url': 'https://api.hh.ru/employers/2198536',
#      'alternate_url': 'https://hh.ru/employer/2198536',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2198536',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Обязательно высшее образование в области <highlighttext>психологии</highlighttext> или профессиональная переподготовка. Стрессоустойчивость, готовность к общению с большим количеством людей, ответственность, высокий уровень...',
#      'responsibility': 'Проведение мастер-классов на темы, связанные с поиском работы. Проведение индивидуальных карьерных консультаций и сопровождение слушателей/выпускников Центра. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '17', 'name': 'Бизнес-тренер'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98380571',
#     'premium': False,
#     'name': 'Мобильный продавец в магазин здорового питания',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 80000, 'to': 150000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-04T06:49:01+0300',
#     'created_at': '2024-05-04T06:49:01+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98380571',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98380571?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98380571',
#     'relations': [],
#     'employer': {'id': '3036416',
#      'name': 'Департамент Ф53',
#      'url': 'https://api.hh.ru/employers/3036416',
#      'alternate_url': 'https://hh.ru/employer/3036416',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1258673.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/6655022.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6655023.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3036416',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Дружелюбный настрой. Готовность к проведению смены динамично и активно. Посещение нескольких магазинов. Готовность к физическим нагрузкам. Общение с разными клиентами...',
#      'responsibility': 'Консультировать и помогать покупателям. Развитие и раскрутка новых магазинов в Москве, Московской области. Работа с кассой. Оформление витрин и выкладка...'},
#     'contacts': None,
#     'schedule': {'id': 'shift', 'name': 'Сменный график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '97',
#       'name': 'Продавец-консультант, продавец-кассир'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98310354',
#     'premium': False,
#     'name': 'Продавец медицинской оптики (г. Москва)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-03T10:33:12+0300',
#     'created_at': '2024-05-03T10:33:12+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98310354',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98310354?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98310354',
#     'relations': [],
#     'employer': {'id': '726371',
#      'name': 'АЙКРАФТ',
#      'url': 'https://api.hh.ru/employers/726371',
#      'alternate_url': 'https://hh.ru/employer/726371',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/3939936.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/3939935.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/874765.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=726371',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Вы умеете и любите общаться с людьми. Забота о клиенте для Вас - приоритет. Вы амбициозны и стремитесь много зарабатывать. ',
#      'responsibility': 'Консультация покупателей при выборе линз, оправ, солнцезащитных очков и аксессуаров. Оформление продажи товаров, услуг. Забота о зрении клиентов. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '70',
#       'name': 'Менеджер по продажам, менеджер по работе с клиентами'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97928532',
#     'premium': False,
#     'name': 'Психолог',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 140000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-25T17:08:26+0300',
#     'created_at': '2024-04-25T17:08:26+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97928532',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97928532?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97928532',
#     'relations': [],
#     'employer': {'id': '1493338',
#      'name': 'Шереметьево Безопасность',
#      'url': 'https://api.hh.ru/employers/1493338',
#      'alternate_url': 'https://hh.ru/employer/1493338',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2348001.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/2348000.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/476537.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1493338',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Обязательно иметь подтвержденный непрерывный стаж работы в области <highlighttext>психологии</highlighttext> не менее 3-х лет. Высшее образование по направлению "<highlighttext>Психология</highlighttext>". ',
#      'responsibility': 'Проведение психологического отбора и профессиональной ориентации работников. Проведение оценки соответствия работников требованиям, предъявляемым к специальности, должности по профессионально важным качествам...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '101', 'name': 'Психолог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98380680',
#     'premium': False,
#     'name': 'Мобильный кассир в магазин здорового питания',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 65000, 'to': None, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-04T06:52:49+0300',
#     'created_at': '2024-05-04T06:52:49+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98380680',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98380680?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98380680',
#     'relations': [],
#     'employer': {'id': '3036416',
#      'name': 'Департамент Ф53',
#      'url': 'https://api.hh.ru/employers/3036416',
#      'alternate_url': 'https://hh.ru/employer/3036416',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1258673.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/6655022.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6655023.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3036416',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Готовность к активной и динамичной смене. Готовность к командировкам. Готовность к работе в разных магазинах. Дружелюбный настрой. Готовность к общению...',
#      'responsibility': 'Консультировать и обслуживать покупателей. Работа в разных магазинах и командировки. Повышение плановых показателей. Презентация товара покупателям. Работать с кассой. '},
#     'contacts': None,
#     'schedule': {'id': 'shift', 'name': 'Сменный график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '51', 'name': 'Кассир-операционист'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   'found': 5940,
#   'pages': 200,
#   'page': 0,
#   'per_page': 10,
#   'clusters': None,
#   'arguments': None,
#   'fixes': None,
#   'suggests': None,
# ...
#     'professional_roles': [{'id': '132',
#       'name': 'Учитель, преподаватель, педагог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98595839',
#     'premium': False,
#     'name': 'Учитель английского языка (ул. Заморенова, 29)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 100000, 'to': None, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'улица Заморенова',
#      'building': '29',
#      'lat': 55.760981,
#      'lng': 37.566458,
#      'description': None,
#      'raw': 'Москва, улица Заморенова, 29',
#      'metro': None,
#      'metro_stations': [],
#      'id': '161685'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-08T09:57:42+0300',
#     'created_at': '2024-05-08T09:57:42+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98595839',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98595839?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98595839',
#     'relations': [],
#     'employer': {'id': '912017',
#      'name': 'Московская Экономическая Школа (МЭШ)',
#      'url': 'https://api.hh.ru/employers/912017',
#      'alternate_url': 'https://hh.ru/employer/912017',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/113810.BMP',
#       '240': 'https://img.hhcdn.ru/employer-logo/1049952.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/1049951.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=912017',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее профессиональное образование. Преподавательский стаж не менее пяти лет. Первая или высшая квалификационная категория. Уверенный пользователь ПК. Опыт проектной деятельности...',
#      'responsibility': 'Учить детей учиться! Преподавания английского языка в начальной и основной школе. Участие в разработке образовательной программы. Долгосрочное планирование и комплексное...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '132',
#       'name': 'Учитель, преподаватель, педагог'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98633273',
#     'premium': False,
#     'name': 'Специалист поддержки в текстовых каналах (без звонков)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 30000, 'to': 45000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-08T18:16:21+0300',
#     'created_at': '2024-05-08T18:16:21+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98633273',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98633273?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98633273',
#     'relations': [],
#     'employer': {'id': '3731347',
#      'name': 'Онлайн-школа Тетрика',
#      'url': 'https://api.hh.ru/employers/3731347',
#      'alternate_url': 'https://hh.ru/employer/3731347',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/785147.jpg',
#       '240': 'https://img.hhcdn.ru/employer-logo/3581480.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/3581479.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3731347',
#      'accredited_it_employer': True,
#      'trusted': True},
#     'snippet': {'requirement': 'Уверенно пользуешься компьютером, обладатель быстрого и стабильного интернета, компьютера или ноутбука.',
#      'responsibility': 'Оперативно решать точечные запросы клиентов: текущие вопросы по отмене и переносу занятия, запросы на подбор <highlighttext>преподавателя</highlighttext>, уточнять, почему ученика нет...'},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [{'id': 'start_after_sixteen',
#       'name': 'Можно начинать работать после 16:00'}],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '40', 'name': 'Другое'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97868447',
#     'premium': False,
#     'name': 'Преподаватель творческих мастерских',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 25000, 'to': 30000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'улица Остоженка',
#      'building': None,
#      'lat': 55.741657,
#      'lng': 37.59878,
#      'description': None,
#      'raw': 'Москва, улица Остоженка',
#      'metro': {'station_name': 'Кропоткинская',
#       'line_name': 'Сокольническая',
#       'station_id': '1.64',
#       'line_id': '1',
#       'lat': 55.745297,
#       'lng': 37.604217},
#      'metro_stations': [{'station_name': 'Кропоткинская',
#        'line_name': 'Сокольническая',
#        'station_id': '1.64',
#        'line_id': '1',
#        'lat': 55.745297,
#        'lng': 37.604217},
#       {'station_name': 'Парк культуры',
#        'line_name': 'Сокольническая',
#        'station_id': '1.103',
#        'line_id': '1',
#        'lat': 55.736163,
#        'lng': 37.595027},
#       {'station_name': 'Парк культуры',
#        'line_name': 'Кольцевая',
#        'station_id': '5.104',
#        'line_id': '5',
#        'lat': 55.735221,
#        'lng': 37.593095}],
#      'id': '171385'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-25T08:12:24+0300',
#     'created_at': '2024-04-25T08:12:24+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97868447',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97868447?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97868447',
#     'relations': [],
#     'employer': {'id': '143166',
#      'name': 'Московский Дом фотографии',
#      'url': 'https://api.hh.ru/employers/143166',
#      'alternate_url': 'https://hh.ru/employer/143166',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/723785.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/723786.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/201709.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=143166',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Художественное или педагогическое образование. Пунктуальность. Коммуникабельность, умение наладить контакт с посетителями.',
#      'responsibility': 'Проведение творческих мастерских для детей и взрослых в музее. Разработка мастер-классов, подготовка необходимых материалов.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [{'id': 'only_saturday_and_sunday',
#       'name': 'Работа только по\xa0сб\xa0и\xa0вс'}],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98628213',
#     'premium': False,
#     'name': 'Специалист по кадровому делопроизводству',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 70000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-08T16:38:05+0300',
#     'created_at': '2024-05-08T16:38:05+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98628213',
#     'branding': {'type': 'CONSTRUCTOR', 'tariff': 'BASIC'},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98628213?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98628213',
#     'relations': [],
#     'employer': {'id': '5744540',
#      'name': 'Онлайн-школа Фоксфорд',
#      'url': 'https://api.hh.ru/employers/5744540',
#      'alternate_url': 'https://hh.ru/employer/5744540',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1005354.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5642196.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/5642197.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5744540',
#      'accredited_it_employer': True,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в отделе кадров от 2 лет. Отличное знание трудового законодательства РФ (в том числе: принцип расчета выплат работникам...',
#      'responsibility': 'Оформлять прием, перемещения и увольнения сотрудников. Оформлять приказы на командировку, отгулы, отпуска. Составлять и контролировать график отпусков сотрудников. '},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '117', 'name': 'Специалист по кадрам'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '97404984',
#     'premium': False,
#     'name': 'Корректор детской литературы (гибридный график)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-19T10:23:22+0300',
#     'created_at': '2024-04-19T10:23:22+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=97404984',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/97404984?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/97404984',
#     'relations': [],
#     'employer': {'id': '223593',
#      'name': 'Издательство МОЗАИКА-СИНТЕЗ',
#      'url': 'https://api.hh.ru/employers/223593',
#      'alternate_url': 'https://hh.ru/employer/223593',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/989609.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5579248.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/5579249.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=223593',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы корректором (будет прекрасно, если это опыт в детской литературе). Профильное высшее образование (специальное или филологическое). Хорошее владение русским...',
#      'responsibility': 'Вычитка текстов детской, методической и рекламной тематики. Исправление пунктуационных, орфографических, стилистических ошибок. Поиск в Интернете и сверка фактов.'},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '55',
#       'name': 'Копирайтер, редактор, корректор'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98777685',
#     'premium': False,
#     'name': 'QA Manual (Middle)',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T11:00:07+0300',
#     'created_at': '2024-05-13T11:00:07+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98777685',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98777685?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98777685',
#     'relations': [],
#     'employer': {'id': '4484134',
#      'name': 'Девелоника',
#      'url': 'https://api.hh.ru/employers/4484134',
#      'alternate_url': 'https://hh.ru/employer/4484134',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6552209.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/6552210.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1232942.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4484134',
#      'accredited_it_employer': True,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в качестве тестировщика не менее 2 лет, преимущественно в тестировании веба и бекенда. Понимание процесса разработки и тестирования. ',
#      'responsibility': 'Самостоятельное проведение функционального, регрессионного, интеграционного и других видов тестирования, необходимых для обеспечения качества на проекте(в том числе анализ и...'},
#     'contacts': None,
#     'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   'found': 3020,
#   'pages': 200,
#   'page': 0,
#   'per_page': 10,
#   'clusters': None,
#   'arguments': None,
#   'fixes': None,
#   'suggests': None,
#   'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&items_on_page=10&text=%D1%83%D1%87%D0%B8%D1%82%D0%B5%D0%BB%D1%8C'}]

# %% [markdown]
# (1 балл) Посчитайте сколько всего найдено вакансий:

# %%
l = [[jobs[i], data[i]['found']] for i in range(5)]
print(l)
# Out:
# [['мясник', 137], ['психолог', 5940], ['уборщик', 2695], ['массажист', 564], ['учитель', 3020]]

# %%
print(sum(data[i]['found'] for i in range(5)))
# Out:
# 12356

# %% [markdown]
# (1 балл) Создайте структуру данных, которая будет хранить в себе имя компании и ее координаты (широта и долгота):

# %%
class Company:
    def __init__(self, name, lat, lng):
      self.name = name
      self.lat = lat
      self.lng = lng

# %% [markdown]
# ```
# # Выбран кодовый формат
# ```
#
# (1 балл) Создайте экземпляр этой структуры данных для каждой компании, которая выставила вакансию:

# %%
# your code here

# %% [markdown]
# (1 балл) Найдите количество вакансий, у которых заданы координаты (значения данных может быть пустым):

# %%
# your code here

# %% [markdown]
# (1 балл) Отберите вакансии, которые расположены в пределах МКАД (можно грубо):

# %%
# your code here

# %% [markdown]
# (1 балл) Постройте график в координатах "широта-долгота" для отображения вакансий внутри МКАД (не забывайте прописать прозрачность, чтобы увидеть скопления):

# %%
# your code here

# %% [markdown]
# (1 балл) Нанесите все точки вакансий на карту (для этого вам поможет данная <a target="_blank" href="https://plotly.com/python/mapbox-layers/">документации</a>, не забудьте про прозрачность и центрирование по Москве):

# %%
# your code here

# %% [markdown]
# (2 балла) **Сделайте выводы о проделанной работе:**

# %% [markdown]
# >*Подсказки для маленьких: Что вы можете сказать про районы Москвы? Что вы можете сказать про зарплаты? Что вы можете сказать про спрос?*

# %% [markdown]
# Ваши выводы здесь :)

# %% [markdown]
# ## Задание 2. Анализ данных - 20 баллов

# %% [markdown]
# Вам предстоит проанализировать датасет, содержащий информацию об бриллианта, их стоимости и остальных характеристиках.

# %% [markdown]
# Поясним значения хранящиеся в колонках:
# *   `cut` - огранка бриллианта (относится к одной из примерно 10 наиболее распространенных)
# *   `color` - цвет бриллианта, прозрачные бриллианты имеют градацию `D-Z`, "более высокие" буквы - более желтоватые, но часто имеют лучшие значения, поскольку цвет трудно определить один раз в кольце
# *   `clarity` - чистота бриллианта, наличие включений (внутренних дефектов), чем меньше и мельче, тем лучше
# *   `carat_weight` - масса бриллианта (слабо связана с размером бриллианта, т.к. огранка и качество огранки, как правило, играют большую роль)
# *   `cut_quality` - качество ограники по системе оценки GIA Cut
# *   `lab` - лаборатория оценивания
# *   `meas_length` - длина бриллианта
# *   `meas_width` - ширина бриллианта
# *   `meas_depth` - глубина бриллианта
# *   `total_sales_price` - цена бриллианта в долларах.
# *    **и прочие колонки**

# %% [markdown]
# Скачаем данные:

# %%
# !gdown 10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8
# To: /content/diamonds.csv
# 100% 35.4M/35.4M [00:00<00:00, 146MB/s]

# %% [markdown]
# Создадим DataFrame:

# %%
import pandas as pd

diamonds = pd.read_csv("diamonds.csv")
diamonds
# Out:
#         Unnamed: 0       cut    color clarity  carat_weight cut_quality  lab  \
# 0                0     Round        E    VVS2          0.09   Excellent  IGI
# 1                1     Round        E    VVS2          0.09   Very Good  IGI
# 2                2     Round        E    VVS2          0.09   Excellent  IGI
# 3                3     Round        E    VVS2          0.09   Excellent  IGI
# 4                4     Round        E    VVS2          0.09   Very Good  IGI
# ...            ...       ...      ...     ...           ...         ...  ...
# 219698      219699     Round        E     VS1         10.65   Excellent  GIA
# 219699      219700   Radiant  unknown     VS2          5.17     unknown  GIA
# 219700      219701     Round        E     VS1         18.07   Excellent  GIA
# 219701      219702  Princess  unknown     SI2          0.90     unknown  GIA
# 219702      219703      Pear  unknown    VVS2         10.03     unknown  GIA
#
#          symmetry     polish eye_clean  ... meas_depth girdle_min  girdle_max  \
# 0       Very Good  Very Good   unknown  ...       1.79          M           M
# 1       Very Good  Very Good   unknown  ...       1.78        STK         STK
# 2       Very Good  Very Good   unknown  ...       1.77         TN           M
# 3       Very Good  Very Good   unknown  ...       1.78          M         STK
# 4       Very Good  Excellent   unknown  ...       1.82        STK         STK
# ...           ...        ...       ...  ...        ...        ...         ...
# 219698  Excellent  Excellent   unknown  ...       8.66          M         STK
# 219699  Very Good  Very Good   unknown  ...       5.71         TK         XTK
# 219700  Excellent  Excellent   unknown  ...      10.20         TN           M
# 219701       Good       Good   unknown  ...       3.47        XTN         VTK
# 219702  Very Good  Excellent   unknown  ...       7.39    unknown     unknown
#
#         fluor_color  fluor_intensity  fancy_color_dominant_color  \
# 0           unknown              NaN                     unknown
# 1           unknown              NaN                     unknown
# 2           unknown              NaN                     unknown
# 3           unknown              NaN                     unknown
# 4           unknown              NaN                     unknown
# ...             ...              ...                         ...
# 219698      unknown              NaN                     unknown
# 219699      unknown              NaN                       Green
# 219700      unknown              NaN                     unknown
# 219701      unknown            Faint                         Red
# 219702      unknown              NaN                      Yellow
#
#         fancy_color_secondary_color fancy_color_overtone  \
# 0                           unknown              unknown
# 1                           unknown              unknown
# 2                           unknown              unknown
# 3                           unknown              unknown
# 4                           unknown              unknown
# ...                             ...                  ...
# 219698                      unknown              unknown
# 219699                      unknown                  NaN
# 219700                      unknown              unknown
# 219701                      unknown              unknown
# 219702                      unknown              unknown
#
#        fancy_color_intensity total_sales_price
# 0                    unknown               200
# 1                    unknown               200
# 2                    unknown               200
# 3                    unknown               200
# 4                    unknown               200
# ...                      ...               ...
# 219698               unknown           1210692
# 219699           Fancy Light           1292500
# 219700               unknown           1315496
# 219701                 Fancy           1350000
# 219702           Fancy Vivid           1449881
#
# [219703 rows x 26 columns]

# %% [markdown]
# (0.5 балла) Выведете первые 5 строк датасета:

# %%
diamonds.head()
# Out:
#    Unnamed: 0    cut color clarity  carat_weight cut_quality  lab   symmetry  \
# 0           0  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 1           1  Round     E    VVS2          0.09   Very Good  IGI  Very Good
# 2           2  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 3           3  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 4           4  Round     E    VVS2          0.09   Very Good  IGI  Very Good
#
#       polish eye_clean  ... meas_depth girdle_min  girdle_max  fluor_color  \
# 0  Very Good   unknown  ...       1.79          M           M      unknown
# 1  Very Good   unknown  ...       1.78        STK         STK      unknown
# 2  Very Good   unknown  ...       1.77         TN           M      unknown
# 3  Very Good   unknown  ...       1.78          M         STK      unknown
# 4  Excellent   unknown  ...       1.82        STK         STK      unknown
#
#    fluor_intensity  fancy_color_dominant_color  fancy_color_secondary_color  \
# 0              NaN                     unknown                      unknown
# 1              NaN                     unknown                      unknown
# 2              NaN                     unknown                      unknown
# 3              NaN                     unknown                      unknown
# 4              NaN                     unknown                      unknown
#
#   fancy_color_overtone fancy_color_intensity total_sales_price
# 0              unknown               unknown               200
# 1              unknown               unknown               200
# 2              unknown               unknown               200
# 3              unknown               unknown               200
# 4              unknown               unknown               200
#
# [5 rows x 26 columns]

# %% [markdown]
# (0.5 балла) Найдите количество бриллиантов всего в данном датасете:

# %%
len(diamonds)
# Out:
# 219703

# %%
diamonds.shape[0]
# Out:
# 219703

# %% [markdown]
# (0.5 балла) Выведите максимальную и минимальную цену бриллианта в формате `номер - цена`:

# %%
l = []
min_name, min_price = -1, 1e100
max_name, max_price = -1, 0

for i, price in enumerate(diamonds["total_sales_price"]):
  if price > max_price:
    max_name, max_price = price, i
  if price < min_price:
    min_name, min_price = price, i
print(max_name, "-", max_price)

print(min_name, "-", min_price)
# Out:
# 1449881 - 219702
# 200 - 0

# %% [markdown]
# (1 балл) Посчитайте количество пропусков (пропуском считается значение `unknown` или `None`):

# %%
# your code here

# %% [markdown]
# (1 балл) Найдите в каких столбцах присутствуют пропуски:

# %%
# your code here

# %% [markdown]
# В нашем датасете присутствуют колонки, которые начинаются с `fancy_color_` или `fluor_`. Большинство значений в этих колонках - `unknown` или `None`, поэтому мы считаем их малоинформативными.

# %% [markdown]
# Ваша задача:

# %% [markdown]
# 1. (0.5 балла) найти количество таких колонок, которые начинаются с `fancy_color_` или `fluor_`:

# %%
l = []
for i in list(diamonds.columns.values):
  if i.startswith("fancy_color_") or i.startswith("fluor_"):
      l.append(i)

print(l)
# Out:
# ['fluor_color', 'fluor_intensity', 'fancy_color_dominant_color', 'fancy_color_secondary_color', 'fancy_color_overtone', 'fancy_color_intensity']

# %%
len(l)
# Out:
# 6

# %% [markdown]
# 2. (0.5 балла) найти количество информативных (не `None` или `unknown`) значений в этих колонках:

# %% [markdown]
# 3. (0.5 балла) удалить данные колонки из датасета, сохранив изменения (в дальнейшем работаем измененным датасетом):

# %%
diamonds = diamonds.drop(columns = l)
diamonds
# Out:
#         Unnamed: 0       cut    color clarity  carat_weight cut_quality  lab  \
# 0                0     Round        E    VVS2          0.09   Excellent  IGI
# 1                1     Round        E    VVS2          0.09   Very Good  IGI
# 2                2     Round        E    VVS2          0.09   Excellent  IGI
# 3                3     Round        E    VVS2          0.09   Excellent  IGI
# 4                4     Round        E    VVS2          0.09   Very Good  IGI
# ...            ...       ...      ...     ...           ...         ...  ...
# 219698      219699     Round        E     VS1         10.65   Excellent  GIA
# 219699      219700   Radiant  unknown     VS2          5.17     unknown  GIA
# 219700      219701     Round        E     VS1         18.07   Excellent  GIA
# 219701      219702  Princess  unknown     SI2          0.90     unknown  GIA
# 219702      219703      Pear  unknown    VVS2         10.03     unknown  GIA
#
#          symmetry     polish eye_clean culet_size culet_condition  \
# 0       Very Good  Very Good   unknown          N         unknown
# 1       Very Good  Very Good   unknown          N         unknown
# 2       Very Good  Very Good   unknown    unknown         unknown
# 3       Very Good  Very Good   unknown    unknown         unknown
# 4       Very Good  Excellent   unknown          N         unknown
# ...           ...        ...       ...        ...             ...
# 219698  Excellent  Excellent   unknown          N         unknown
# 219699  Very Good  Very Good   unknown    unknown         unknown
# 219700  Excellent  Excellent   unknown          N         unknown
# 219701       Good       Good   unknown          N         unknown
# 219702  Very Good  Excellent   unknown    unknown         unknown
#
#         depth_percent  table_percent  meas_length  meas_width  meas_depth  \
# 0                62.7           59.0         2.85        2.87        1.79
# 1                61.9           59.0         2.84        2.89        1.78
# 2                61.1           59.0         2.88        2.90        1.77
# 3                62.0           59.0         2.86        2.88        1.78
# 4                64.9           58.5         2.79        2.83        1.82
# ...               ...            ...          ...         ...         ...
# 219698           61.3           58.0        14.06       14.18        8.66
# 219699           64.8           65.0        11.55        8.81        5.71
# 219700           60.2           59.0        17.06       17.10       10.20
# 219701           70.8           72.0         5.22        4.90        3.47
# 219702           66.7           65.0        15.61       11.09        7.39
#
#        girdle_min girdle_max  total_sales_price
# 0               M          M                200
# 1             STK        STK                200
# 2              TN          M                200
# 3               M        STK                200
# 4             STK        STK                200
# ...           ...        ...                ...
# 219698          M        STK            1210692
# 219699         TK        XTK            1292500
# 219700         TN          M            1315496
# 219701        XTN        VTK            1350000
# 219702    unknown    unknown            1449881
#
# [219703 rows x 20 columns]

# %% [markdown]
# (1 балл) Проделайте тоже самое для колонок, начинающихся с `culet_`:

# %%
# your code here

# %% [markdown]
# (1 балл) Посчитайте сколько бы стоил (в тысячах долларов) сейф, в котором хранились бы все бриллианты из датасета:

# %%
diamonds["total_sales_price"].sum() // 1000
# Out:
# 1517721

# %% [markdown]
# Немного необоснованных манипуляций.

# %% [markdown]
# (1 балл) Выберите из датасета строки с четными индексами и выведете значения (не меняя нумерацию индексов):

# %%
diamonds[diamonds["Unnamed: 0"] % 2 == 0]
# Out:
#         Unnamed: 0               cut    color clarity  carat_weight  \
# 0                0             Round        E    VVS2          0.09
# 2                2             Round        E    VVS2          0.09
# 4                4             Round        E    VVS2          0.09
# 6                6             Round        E    VVS2          0.09
# 8                8             Round        E    VVS2          0.09
# ...            ...               ...      ...     ...           ...
# 219693      219694             Round        E      IF         12.52
# 219695      219696  Cushion Modified  unknown    VVS1         10.00
# 219697      219698              Oval  unknown     VS1         10.04
# 219699      219700           Radiant  unknown     VS2          5.17
# 219701      219702          Princess  unknown     SI2          0.90
#
#        cut_quality  lab   symmetry     polish eye_clean culet_size  \
# 0        Excellent  IGI  Very Good  Very Good   unknown          N
# 2        Excellent  IGI  Very Good  Very Good   unknown    unknown
# 4        Very Good  IGI  Very Good  Excellent   unknown          N
# 6        Very Good  IGI  Very Good  Very Good   unknown    unknown
# 8        Very Good  IGI  Very Good  Very Good   unknown          N
# ...            ...  ...        ...        ...       ...        ...
# 219693   Excellent  GIA  Excellent  Excellent   unknown    unknown
# 219695     unknown  GIA  Very Good  Excellent   unknown    unknown
# 219697     unknown  GIA  Excellent  Excellent   unknown    unknown
# 219699     unknown  GIA  Very Good  Very Good   unknown    unknown
# 219701     unknown  GIA       Good       Good   unknown          N
#
#        culet_condition  depth_percent  table_percent  meas_length  meas_width  \
# 0              unknown           62.7           59.0         2.85        2.87
# 2              unknown           61.1           59.0         2.88        2.90
# 4              unknown           64.9           58.5         2.79        2.83
# 6              Abraded           64.0           57.0         2.85        2.88
# 8              unknown           63.5           59.5         2.89        2.92
# ...                ...            ...            ...          ...         ...
# 219693         unknown           62.1           58.0        14.84       14.91
# 219695         unknown           78.1           60.0        11.78       10.84
# 219697         unknown           72.8           55.0        14.13       10.86
# 219699         unknown           64.8           65.0        11.55        8.81
# 219701         unknown           70.8           72.0         5.22        4.90
#
#         meas_depth girdle_min girdle_max  total_sales_price
# 0             1.79          M          M                200
# 2             1.77         TN          M                200
# 4             1.82        STK        STK                200
# 6             1.84        STK        STK                200
# 8             1.85        STK         TK                200
# ...            ...        ...        ...                ...
# 219693        9.24    unknown    unknown            1121792
# 219695        8.47    unknown    unknown            1124122
# 219697        7.90    unknown    unknown            1161102
# 219699        5.71         TK        XTK            1292500
# 219701        3.47        XTN        VTK            1350000
#
# [109852 rows x 20 columns]

# %% [markdown]
# (0.5 балла) А теперь с индексами, кратными 6:

# %%
diamonds[diamonds["Unnamed: 0"] % 6 == 0]
# Out:
#         Unnamed: 0               cut    color clarity  carat_weight  \
# 0                0             Round        E    VVS2          0.09
# 6                6             Round        E    VVS2          0.09
# 12              12             Round        E    VVS2          0.09
# 18              18             Round        E    VVS2          0.09
# 24              24             Round        L      I1          0.34
# ...            ...               ...      ...     ...           ...
# 219677      219678             Round        G     VS1         10.14
# 219683      219684              Pear  unknown     VS2          1.51
# 219689      219690             Round        F      IF         10.66
# 219695      219696  Cushion Modified  unknown    VVS1         10.00
# 219701      219702          Princess  unknown     SI2          0.90
#
#        cut_quality  lab   symmetry     polish eye_clean culet_size  \
# 0        Excellent  IGI  Very Good  Very Good   unknown          N
# 6        Very Good  IGI  Very Good  Very Good   unknown    unknown
# 12       Very Good  IGI  Very Good  Very Good   unknown          N
# 18       Excellent  IGI  Very Good  Very Good   unknown          N
# 24       Excellent  IGI  Excellent  Excellent   unknown    unknown
# ...            ...  ...        ...        ...       ...        ...
# 219677   Excellent  GIA  Excellent  Excellent   unknown          N
# 219683     unknown  GIA  Very Good  Very Good   unknown          N
# 219689   Excellent  GIA  Excellent  Excellent   unknown          N
# 219695     unknown  GIA  Very Good  Excellent   unknown    unknown
# 219701     unknown  GIA       Good       Good   unknown          N
#
#        culet_condition  depth_percent  table_percent  meas_length  meas_width  \
# 0              unknown           62.7           59.0         2.85        2.87
# 6              Abraded           64.0           57.0         2.85        2.88
# 12             unknown           61.8           58.5         2.85        2.89
# 18             unknown           61.0           60.0         2.91        2.92
# 24             unknown            0.0            0.0         0.00        0.00
# ...                ...            ...            ...          ...         ...
# 219677         unknown           61.8           59.0        13.84       13.88
# 219683         unknown           63.8           59.0        10.73        5.61
# 219689         unknown           61.4           58.0        14.14       14.16
# 219695         unknown           78.1           60.0        11.78       10.84
# 219701         unknown           70.8           72.0         5.22        4.90
#
#         meas_depth girdle_min girdle_max  total_sales_price
# 0             1.79          M          M                200
# 6             1.84        STK        STK                200
# 12            1.77        STK         TK                200
# 18            1.78          M          M                200
# 24            0.00    unknown    unknown                204
# ...            ...        ...        ...                ...
# 219677        8.56          M        STK             851760
# 219683        3.58    unknown    unknown             966401
# 219689        8.69          M        STK            1034844
# 219695        8.47    unknown    unknown            1124122
# 219701        3.47        XTN        VTK            1350000
#
# [36618 rows x 20 columns]

# %% [markdown]
# (1 балл) Выберете из датасета только категорильные признаки и выведете датасет:

# %%
# your code here

# %% [markdown]
# >**Примечание**
# >
# >Данный датасет можно использовать для задания 3 (с использованием `sklearn`)

# %% [markdown]
# (0.5 балла) Выберете столбец с данными о цене бриллиантов и домножите его на тот столбец, только транспонированный, и выведите полученную матрицу:

# %%
# your code here

# %% [markdown]
# ### Построение графиков

# %% [markdown]
# **Требования к графику:**
#
# 1.   График должен быть подписан
# 2.   Оси должны быть подписаны
# 3.   Должна быть легенда графика
# 4.   График должен быть информативным (желательно без сильных выбросов)
#
# **Все надписи на русском языке!**

# %% [markdown]
# >**Примечание**
# >
# >График необходимо строить для очищенных данных - в них не должно быть пропусков по осям, по которым строите график. При этом **не перезатирайте** имеющийся датафрейм!

# %% [markdown]
# (2 балла) Постройте график `цвет бриллианта - стоимость`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `лабараторная оценка - кол-во бриллиантов`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `вес бриллианта - стоимость`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `система оценки GIA Cut - кол-во бриллиантов`:

# %%
# your code here

# %% [markdown]
# (2 балла) **Сделайте выводы по построенным графикам:**

# %% [markdown]
# >*Подсказка для маленьких: Что вы можете сказать о графиках полученных выше для данного датасета?*

# %% [markdown]
# Ваши выводы здесь :)

# %% [markdown]
# ## Задание 3. Модель - 30 баллов

# %% [markdown]
# В данном задании вам предстоит построить классифицирующую модель размер алмаза и его стоимости, а затем оценить полученную модель.

# %% [markdown]
# >**Примечание**
# >
# >Данная модель не претендует на самый верный индикатор стоимости алмаза, ведь мы не учитываем ничего больше чем стоимость алмаза. Исключительно для образовательных целей :)

# %% [markdown]
# Для построения модели нам понадобится 4 столбца, а именно:
# - `meas_length`
# - `meas_width`
# - `meas_depth`
# - `total_sales_price`
#
# От остальных столбцов можно избавиться.

# %% [markdown]
# (1 балл) Создайте новый датасет и выведите его первые 10 строк:

# %%
data_set = diamonds[["meas_length", "meas_width", "meas_depth", "total_sales_price"]]
data_set.head(10)
# Out:
#    meas_length  meas_width  meas_depth  total_sales_price
# 0         2.85        2.87        1.79                200
# 1         2.84        2.89        1.78                200
# 2         2.88        2.90        1.77                200
# 3         2.86        2.88        1.78                200
# 4         2.79        2.83        1.82                200
# 5         2.95        2.99        1.81                200
# 6         2.85        2.88        1.84                200
# 7         2.86        2.89        1.78                200
# 8         2.89        2.92        1.85                200
# 9         2.83        2.87        1.80                200

# %% [markdown]
# (1 балл) Перемешайте строки в датафрейме случайным образом:

# %%
data_set = data_set.sample(frac = 1)
data_set
# Out:
#         meas_length  meas_width  meas_depth  total_sales_price
# 50210          4.23        4.28        2.69                924
# 167261         6.09        6.15        3.85               5279
# 195753         7.12        5.69        4.08              13227
# 43985          4.32        4.33        2.69                888
# 115736         4.37        4.34        3.32               2130
# ...             ...         ...         ...                ...
# 117614         6.41        4.91        3.41               2304
# 205213         7.82        7.89        4.98              19187
# 18441          4.34        4.36        2.66                702
# 156685         5.57        5.20        3.71               4221
# 78136          4.55        4.58        2.79               1172
#
# [219703 rows x 4 columns]

# %% [markdown]
# (1 балл) Сформируем новую колонку - для каждого бриллианта найдем сумму Минковского (p=3) по 3 измерениям бриллианта:

# %%
data_set["sum"] = data_set["meas_length"] + data_set["meas_width"] + data_set["meas_depth"]
data_set
# Out:
#         meas_length  meas_width  meas_depth  total_sales_price    sum
# 50210          4.23        4.28        2.69                924  11.20
# 167261         6.09        6.15        3.85               5279  16.09
# 195753         7.12        5.69        4.08              13227  16.89
# 43985          4.32        4.33        2.69                888  11.34
# 115736         4.37        4.34        3.32               2130  12.03
# ...             ...         ...         ...                ...    ...
# 117614         6.41        4.91        3.41               2304  14.73
# 205213         7.82        7.89        4.98              19187  20.69
# 18441          4.34        4.36        2.66                702  11.36
# 156685         5.57        5.20        3.71               4221  14.48
# 78136          4.55        4.58        2.79               1172  11.92
#
# [219703 rows x 5 columns]

# %% [markdown]
# (1 балл) Сформируем новый датасет из двух колонок - сумма Минковского и `total_sales_price`:

# %%
sum_data = data_set[["sum", "total_sales_price"]]
sum_data
# Out:
#           sum  total_sales_price
# 50210   11.20                924
# 167261  16.09               5279
# 195753  16.89              13227
# 43985   11.34                888
# 115736  12.03               2130
# ...       ...                ...
# 117614  14.73               2304
# 205213  20.69              19187
# 18441   11.36                702
# 156685  14.48               4221
# 78136   11.92               1172
#
# [219703 rows x 2 columns]

# %% [markdown]
# (1 балл) Разделите вашу выборку на две части в соотношении 8:2 - одна выборка будет для тренировка, а другая для тестов вашей модели:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график зависимости стоимости от вашего нового параметра размера для тренинг-выборки:

# %%
# your code here

# %% [markdown]
# (2 балла) Нанесите на тот же график тестовую выборку, используя другой цвет (не забудьте про параметр прозрачности):

# %%
# your code here

# %% [markdown]
# (3 балла) Найдите для каждой бриллианта из тестовой выборки его "ближайшего соседа" из тренинг-выборки. Для каждого бриллианта из тестовой выборки найдите расстояния до соответствующего ближайшего соседа:

# %%
# your code here

# %% [markdown]
# (3 балла) Найдите насколько сильно (в процентах) отличается цена бриллиантов из тестовой выборки от их соответствующих ближайших соседей:

# %%
# your code here

# %% [markdown]
# **Данная модель является выдумкой автора. Не важен коэффициент ошибки, важны ваши шаги для получения коэффициента.**

# %% [markdown]
# ### Введение в машинное обучение

# %% [markdown]
# Теперь давайте познакомимся с таким сильным инструментом как `sklearn`.

# %% [markdown]
# Вам необходимо:
# 1. выбрать 2 категориальных признака
# 2. на их основе обучить решающее дерево
# 3. оценить среднеквадратичную ошибку цены бриллианта
# 4. сделать пп. 1-3 и выбрать ту пару, которая дает лучший результат
# 5. сделать выводы

# %% [markdown]
# (3 балла) Мы работаем с категориальными признаками, для них не понятно что есть "больше" и "меньше". Поэтому нам нужно предварительно закодировать значения наших признаков, с чем нам поможет [OneHotEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Разбейте датасет на обучающую и тестовую выбору. Для этого вам поможет [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Затем создайте и обучите вашу модель - [DecisionTreeRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Оцените ошибку вашей модели при помощи [mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html):

# %%
# your code here

# %% [markdown]
# (3 балла) **Сделайте выводы какие категориальные признаки лучше:**

# %% [markdown]
# *Подсказки для маленьких: Что вы можете сказать о зависимости по вашей выборке признаков? Какой вы можете сделать вывод об готовых инструментах для работы и написанных Вами?*

# %% [markdown]
# Ваши выводы здесь :)
